# %% [markdown]
# <a href="https://colab.research.google.com/github/LiryelBA/metereologia/blob/main/inmet_natal_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IMPORTS

# %% [markdown]
# ## Bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.preprocessing import LabelEncoder
#imports

# %% [markdown]
# ## Leitura da Tabela

# %%
vari = 'https://raw.githubusercontent.com/LiryelBA/metereologia/main/NATAL%20(A304)_2020-01-01_2020-12-31.csv?token=GHSAT0AAAAAABUMQC6SJQORBJWNPRUNQTLOYUTOIBQ'
dfMet = pd.read_csv(vari, delimiter=";", quotechar='"')

# %% [markdown]
# ## Visualizar a Tabela

# %%
dfMet.head(25)
# Out:
#           Data  Hora (UTC) Temp. Ins. (C) Temp. Max. (C) Temp. Min. (C)  \
# 0   01/01/2020           0           27,3           27,4           27,1
# 1   01/01/2020         100           27,1           27,3           26,8
# 2   01/01/2020         200           27,1           27,1           27,0
# 3   01/01/2020         300           27,1           27,1           26,9
# 4   01/01/2020         400           27,0           27,1           27,0
# 5   01/01/2020         500           26,9           27,0           26,9
# 6   01/01/2020         600           26,8           26,9           26,8
# 7   01/01/2020         700           26,8           26,9           26,8
# 8   01/01/2020         800           26,8           26,9           26,7
# 9   01/01/2020         900           26,8           26,8           26,6
# 10  01/01/2020        1000           27,2           27,3           26,8
# 11  01/01/2020        1100           27,4           27,5           27,2
# 12  01/01/2020        1200           27,4           27,6           27,4
# 13  01/01/2020        1300           28,4           28,4           27,4
# 14  01/01/2020        1400           28,9           29,2           28,4
# 15  01/01/2020        1500           28,0           29,6           28,0
# 16  01/01/2020        1600           28,5           28,6           27,8
# 17  01/01/2020        1700           28,1           29,9           28,1
# 18  01/01/2020        1800           28,0           29,0           27,7
# 19  01/01/2020        1900           27,7           28,4           27,7
# 20  01/01/2020        2000           27,5           28,0           27,5
# 21  01/01/2020        2100           27,1           27,5           27,1
# 22  01/01/2020        2200           27,2           27,2           27,1
# 23  01/01/2020        2300           27,1           27,2           27,1
# 24  02/01/2020           0           27,0           27,2           27,0
#
#    Umi. Ins. (%) Umi. Max. (%) Umi. Min. (%) Pto Orvalho Ins. (C)  \
# 0           80,0          81,0          79,0                 23,7
# 1           81,0          82,0          80,0                 23,5
# 2           80,0          81,0          80,0                 23,3
# 3           81,0          81,0          80,0                 23,5
# 4           81,0          82,0          81,0                 23,4
# 5           81,0          81,0          80,0                 23,3
# 6           82,0          82,0          81,0                 23,4
# 7           82,0          82,0          81,0                 23,4
# 8           81,0          82,0          81,0                 23,3
# 9           82,0          83,0          81,0                 23,4
# 10          80,0          82,0          80,0                 23,4
# 11          79,0          80,0          79,0                 23,5
# 12          80,0          80,0          79,0                 23,6
# 13          76,0          80,0          76,0                 23,9
# 14          74,0          76,0          72,0                 23,7
# 15          76,0          76,0          71,0                 23,4
# 16          74,0          77,0          74,0                 23,5
# 17          75,0          76,0          71,0                 23,3
# 18          76,0          77,0          74,0                 23,4
# 19          76,0          78,0          74,0                 23,1
# 20          78,0          78,0          75,0                 23,3
# 21          78,0          79,0          78,0                 23,0
# 22          79,0          79,0          78,0                 23,3
# 23          80,0          80,0          78,0                 23,3
# 24          81,0          81,0          79,0                 23,4
#
#    Pto Orvalho Max. (C) Pto Orvalho Min. (C) Pressao Ins. (hPa)  \
# 0                  23,8                 23,2             1006,4
# 1                  23,6                 23,4             1006,8
# 2                  23,6                 23,3             1006,7
# 3                  23,5                 23,3             1006,3
# 4                  23,6                 23,4             1005,5
# 5                  23,5                 23,3             1005,2
# 6                  23,4                 23,2             1005,1
# 7                  23,4                 23,3             1005,5
# 8                  23,5                 23,3             1005,9
# 9                  23,6                 23,2             1006,5
# 10                 23,5                 23,3             1007,1
# 11                 23,7                 23,4             1007,2
# 12                 23,8                 23,4             1007,3
# 13                 23,9                 23,3             1007,1
# 14                 24,1                 23,2             1006,7
# 15                 24,3                 23,0             1006,4
# 16                 23,8                 23,1             1005,7
# 17                 24,4                 23,1             1004,7
# 18                 24,1                 23,2             1004,2
# 19                 24,1                 23,1             1004,3
# 20                 23,4                 23,0             1004,8
# 21                 23,4                 23,0             1005,3
# 22                 23,3                 22,9             1005,3
# 23                 23,4                 23,0             1005,9
# 24                 23,5                 23,2             1006,3
#
#    Pressao Max. (hPa) Pressao Min. (hPa) Vel. Vento (m/s) Dir. Vento (m/s)  \
# 0              1006,4             1006,1              2,7            107,0
# 1              1006,8             1006,4              2,7            108,0
# 2              1006,8             1006,7              3,1            103,0
# 3              1006,7             1006,3              2,4            110,0
# 4              1006,3             1005,5              3,2            118,0
# 5              1005,6             1005,2              2,8            111,0
# 6              1005,2             1005,0              2,5            110,0
# 7              1005,5             1005,1              2,3            109,0
# 8              1005,9             1005,5              1,8            103,0
# 9              1006,5             1005,9              1,8            115,0
# 10             1007,1             1006,5              2,2            125,0
# 11             1007,2             1007,1              2,6            124,0
# 12             1007,5             1007,2              3,3            115,0
# 13             1007,3             1007,1              3,2            124,0
# 14             1007,1             1006,7              3,6            126,0
# 15             1006,7             1006,4              2,8            109,0
# 16             1006,4             1005,7              4,2            116,0
# 17             1005,7             1004,7              4,2            123,0
# 18             1004,7             1004,2              3,8            124,0
# 19             1004,4             1004,0              3,7            115,0
# 20             1004,8             1004,3              3,2            127,0
# 21             1005,3             1004,8              2,5            120,0
# 22             1005,4             1005,3              2,8            123,0
# 23             1005,9             1005,3              3,5            110,0
# 24             1006,3             1005,8              2,7            102,0
#
#    Raj. Vento (m/s) Radiacao (KJ/m²) Chuva (mm)
# 0               6,0              NaN        0,0
# 1               6,1              NaN        0,0
# 2               6,3              NaN        0,0
# 3               6,3              NaN        0,0
# 4               5,5              NaN        0,0
# 5               5,8              NaN        0,0
# 6               5,1              NaN        0,0
# 7               4,7              NaN        0,0
# 8               4,1              NaN        0,0
# 9               3,6            14,30        0,0
# 10              4,2           135,50        0,0
# 11              4,8           352,90        0,0
# 12              5,8           364,20        0,0
# 13              5,7           762,90        0,0
# 14              6,5          2088,90        0,0
# 15              6,9          1220,40        0,0
# 16              6,8          1695,90        0,0
# 17              7,2          2160,40        0,0
# 18              6,9          1074,40        0,0
# 19              7,2           902,10        0,0
# 20              6,2           308,20        0,0
# 21              6,2            14,60        0,0
# 22              5,1              NaN        0,0
# 23              6,6              NaN        0,0
# 24              7,0              NaN        0,0

# %% [markdown]
# > ° Na tabela acima de dados metereologicos pode-se observar que há uma leitura de dados aconcetendo de 00:00 até 00:00 do dia seguinte.
#
# > ° Pode-se notar também que na coluna que diz respeito a radiação existem dados incompletos, não lidos. (NaN)

# %% [markdown]
# # Informações sobre a Tabela

# %% [markdown]
# ## Descrições

# %%
#verifica quantas amostras possuem valor NaN por coluna
dfMet.isna().sum()
# Out:
# Data                       0
# Hora (UTC)                 0
# Temp. Ins. (C)           637
# Temp. Max. (C)           641
# Temp. Min. (C)           641
# Umi. Ins. (%)            637
# Umi. Max. (%)            641
# Umi. Min. (%)            641
# Pto Orvalho Ins. (C)     637
# Pto Orvalho Max. (C)     641
# Pto Orvalho Min. (C)     641
# Pressao Ins. (hPa)       637
# Pressao Max. (hPa)       641
# Pressao Min. (hPa)       641
# Vel. Vento (m/s)         637
# Dir. Vento (m/s)         637
# Raj. Vento (m/s)         651
# Radiacao (KJ/m²)        3957
# Chuva (mm)               637
# dtype: int64

# %% [markdown]
# >° Quantidade de dados dessa mesma forma que existem ao longo da tabela inteira

# %%
# Porcentagem dos valores ausentes
dfMet.isna().mean()
# Out:
# Data                    0.000000
# Hora (UTC)              0.000000
# Temp. Ins. (C)          0.072518
# Temp. Max. (C)          0.072974
# Temp. Min. (C)          0.072974
# Umi. Ins. (%)           0.072518
# Umi. Max. (%)           0.072974
# Umi. Min. (%)           0.072974
# Pto Orvalho Ins. (C)    0.072518
# Pto Orvalho Max. (C)    0.072974
# Pto Orvalho Min. (C)    0.072974
# Pressao Ins. (hPa)      0.072518
# Pressao Max. (hPa)      0.072974
# Pressao Min. (hPa)      0.072974
# Vel. Vento (m/s)        0.072518
# Dir. Vento (m/s)        0.072518
# Raj. Vento (m/s)        0.074112
# Radiacao (KJ/m²)        0.450478
# Chuva (mm)              0.072518
# dtype: float64

# %%
# Esse método imprime informações sobre um DataFrame
dfMet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Data                  8784 non-null   object
#  1   Hora (UTC)            8784 non-null   int64
#  2   Temp. Ins. (C)        8147 non-null   object
#  3   Temp. Max. (C)        8143 non-null   object
#  4   Temp. Min. (C)        8143 non-null   object
#  5   Umi. Ins. (%)         8147 non-null   object
#  6   Umi. Max. (%)         8143 non-null   object
#  7   Umi. Min. (%)         8143 non-null   object
#  8   Pto Orvalho Ins. (C)  8147 non-null   object
#  9   Pto Orvalho Max. (C)  8143 non-null   object
#  10  Pto Orvalho Min. (C)  8143 non-null   object
#  11  Pressao Ins. (hPa)    8147 non-null   object
#  12  Pressao Max. (hPa)    8143 non-null   object
#  13  Pressao Min. (hPa)    8143 non-null   object
#  14  Vel. Vento (m/s)      8147 non-null   object
#  15  Dir. Vento (m/s)      8147 non-null   object
#  16  Raj. Vento (m/s)      8133 non-null   object
#  17  Radiacao (KJ/m²)      4827 non-null   object
#  18  Chuva (mm)            8147 non-null   object
# dtypes: int64(1), object(18)
# memory usage: 1.3+ MB

# %% [markdown]
# ## Descrições Numericas

# %%
#descrição estatística das colunas numéricas
dfMet.describe()
# Out:
#         Hora (UTC)
# count  8784.000000
# mean   1150.000000
# std     692.258061
# min       0.000000
# 25%     575.000000
# 50%    1150.000000
# 75%    1725.000000
# max    2300.000000

# %% [markdown]
# >**count:** número de observações não nulas
#
# >**mean:** média dos valores
#
# >**std:**desvio padrão
#
# >**max:** valor máximo
#
# >**min:** valor mínimo

# %%
#inclui apenas colunas categóricas na descrição
dfMet.describe(include='object')
# Out:
#               Data Temp. Ins. (C) Temp. Max. (C) Temp. Min. (C) Umi. Ins. (%)  \
# count         8784           8147           8143           8143          8147
# unique         366            117            122            109            51
# top     01/01/2020           27,7           28,2           27,1          77,0
# freq            24            183            158            190           380
#
#        Umi. Max. (%) Umi. Min. (%) Pto Orvalho Ins. (C) Pto Orvalho Max. (C)  \
# count           8143          8143                 8147                 8143
# unique            46            54                   87                   90
# top             80,0          78,0                 24,0                 23,9
# freq             402           357                  272                  254
#
#        Pto Orvalho Min. (C) Pressao Ins. (hPa) Pressao Max. (hPa)  \
# count                  8143               8147               8143
# unique                   89                113                114
# top                    23,1             1007,2             1007,2
# freq                    257                200                208
#
#        Pressao Min. (hPa) Vel. Vento (m/s) Dir. Vento (m/s) Raj. Vento (m/s)  \
# count                8143             8147             8147             8133
# unique                112               86              279              153
# top                1006,8              3,7            139,0              7,8
# freq                  202              215              167              145
#
#        Radiacao (KJ/m²) Chuva (mm)
# count              4827       8147
# unique             4280         83
# top                0,10        0,0
# freq                 12       7236

# %% [markdown]
# >**unique:** quantidade de valores únicos
#
# >**top:** é o valor mais comum
#
# >**freq:** é a frequência do valor mais comum

# %% [markdown]
# # Limpeza dos dados

# %% [markdown]
# ## Removendo NaN

# %%
# Remoção dos valores nulos
dfMet.dropna(inplace=True) # o default do dropna é axis = 0 (linhas) / axis = 1 apagaria colunas

# %%
#verificação de quantas amostras com valor NaN sobraram em cada coluna
dfMet.isna().sum()
# Out:
# Data                    0
# Hora (UTC)              0
# Temp. Ins. (C)          0
# Temp. Max. (C)          0
# Temp. Min. (C)          0
# Umi. Ins. (%)           0
# Umi. Max. (%)           0
# Umi. Min. (%)           0
# Pto Orvalho Ins. (C)    0
# Pto Orvalho Max. (C)    0
# Pto Orvalho Min. (C)    0
# Pressao Ins. (hPa)      0
# Pressao Max. (hPa)      0
# Pressao Min. (hPa)      0
# Vel. Vento (m/s)        0
# Dir. Vento (m/s)        0
# Raj. Vento (m/s)        0
# Radiacao (KJ/m²)        0
# Chuva (mm)              0
# dtype: int64

# %% [markdown]
# ## Tranformando Object's em float's

# %%
auxiliar = dfMet
datacrono = dfMet[['Data', 'Hora (UTC)']]

# %%
auxiliar = auxiliar.drop(columns=['Data'])
auxiliar = auxiliar.drop(columns=['Hora (UTC)'])

# %%
# Laço responsável por trocar as virgulas por pontos
for colunas in auxiliar:
  auxiliar[colunas] = auxiliar[colunas].str.replace(',', '.')

# %%
# Função responsável por trocar os tipos de dados: String -> Float
auxiliar = auxiliar.astype(float)

# %%
# Mostra o tipo de dados das colunas 
auxiliar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4814 entries, 9 to 8781
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Temp. Ins. (C)        4814 non-null   float64
#  1   Temp. Max. (C)        4814 non-null   float64
#  2   Temp. Min. (C)        4814 non-null   float64
#  3   Umi. Ins. (%)         4814 non-null   float64
#  4   Umi. Max. (%)         4814 non-null   float64
#  5   Umi. Min. (%)         4814 non-null   float64
#  6   Pto Orvalho Ins. (C)  4814 non-null   float64
#  7   Pto Orvalho Max. (C)  4814 non-null   float64
#  8   Pto Orvalho Min. (C)  4814 non-null   float64
#  9   Pressao Ins. (hPa)    4814 non-null   float64
#  10  Pressao Max. (hPa)    4814 non-null   float64
#  11  Pressao Min. (hPa)    4814 non-null   float64
#  12  Vel. Vento (m/s)      4814 non-null   float64
#  13  Dir. Vento (m/s)      4814 non-null   float64
#  14  Raj. Vento (m/s)      4814 non-null   float64
#  15  Radiacao (KJ/m²)      4814 non-null   float64
#  16  Chuva (mm)            4814 non-null   float64
# dtypes: float64(17)
# memory usage: 677.0 KB

# %% [markdown]
# ## Junção de Tabelas

# %%
result = pd.concat([datacrono, auxiliar])

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9628 entries, 9 to 8781
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Data                  4814 non-null   object
#  1   Hora (UTC)            4814 non-null   float64
#  2   Temp. Ins. (C)        4814 non-null   float64
#  3   Temp. Max. (C)        4814 non-null   float64
#  4   Temp. Min. (C)        4814 non-null   float64
#  5   Umi. Ins. (%)         4814 non-null   float64
#  6   Umi. Max. (%)         4814 non-null   float64
#  7   Umi. Min. (%)         4814 non-null   float64
#  8   Pto Orvalho Ins. (C)  4814 non-null   float64
#  9   Pto Orvalho Max. (C)  4814 non-null   float64
#  10  Pto Orvalho Min. (C)  4814 non-null   float64
#  11  Pressao Ins. (hPa)    4814 non-null   float64
#  12  Pressao Max. (hPa)    4814 non-null   float64
#  13  Pressao Min. (hPa)    4814 non-null   float64
#  14  Vel. Vento (m/s)      4814 non-null   float64
#  15  Dir. Vento (m/s)      4814 non-null   float64
#  16  Raj. Vento (m/s)      4814 non-null   float64
#  17  Radiacao (KJ/m²)      4814 non-null   float64
#  18  Chuva (mm)            4814 non-null   float64
# dtypes: float64(18), object(1)
# memory usage: 1.5+ MB

# %%
result.describe()
# Out:
#         Hora (UTC)  Temp. Ins. (C)  Temp. Max. (C)  Temp. Min. (C)  \
# count  4814.000000     4814.000000     4814.000000     4814.000000
# mean   1488.533444       27.558205       28.133299       26.911363
# std     395.572590        1.987888        2.136177        2.007011
# min       0.000000       20.900000       20.900000       20.400000
# 25%    1200.000000       26.400000       26.900000       25.600000
# 50%    1500.000000       27.900000       28.500000       27.300000
# 75%    1800.000000       29.000000       29.700000       28.400000
# max    2300.000000       32.800000       33.500000       31.800000
#
#        Umi. Ins. (%)  Umi. Max. (%)  Umi. Min. (%)  Pto Orvalho Ins. (C)  \
# count    4814.000000    4814.000000    4814.000000           4814.000000
# mean       76.548816      79.592646      73.938097             22.940320
# std         9.166625       8.925019       9.757474              1.378868
# min        39.000000      45.000000      38.000000             14.400000
# 25%        70.000000      73.000000      67.000000             22.000000
# 50%        75.000000      77.000000      72.000000             23.100000
# 75%        82.000000      87.000000      79.000000             24.000000
# max        99.000000      99.000000      99.000000             26.400000
#
#        Pto Orvalho Max. (C)  Pto Orvalho Min. (C)  Pressao Ins. (hPa)  \
# count           4814.000000           4814.000000         4814.000000
# mean              23.491275             22.401080         1007.205442
# std                1.384826              1.385753            1.837855
# min               16.100000             13.800000         1002.200000
# 25%               22.600000             21.500000         1005.900000
# 50%               23.600000             22.600000         1007.200000
# 75%               24.500000             23.400000         1008.400000
# max               27.300000             25.800000         1013.400000
#
#        Pressao Max. (hPa)  Pressao Min. (hPa)  Vel. Vento (m/s)  \
# count         4814.000000         4814.000000       4814.000000
# mean          1007.468446         1006.965870          4.255650
# std              1.823232            1.824197          1.482301
# min           1002.300000         1002.100000          0.300000
# 25%           1006.200000         1005.700000          3.200000
# 50%           1007.400000         1006.900000          4.300000
# 75%           1008.700000         1008.200000          5.300000
# max           1013.600000         1013.300000          8.600000
#
#        Dir. Vento (m/s)  Raj. Vento (m/s)  Radiacao (KJ/m²)   Chuva (mm)
# count       4814.000000       4814.000000       4814.000000  4814.000000
# mean         140.503116          8.491359       1571.910594     0.285044
# std           32.182988          2.548210       1194.035903     1.787113
# min           20.000000          1.400000          0.100000     0.000000
# 25%          124.000000          6.800000        380.550000     0.000000
# 50%          137.000000          8.500000       1502.300000     0.000000
# 75%          153.000000         10.200000       2661.750000     0.000000
# max          353.000000         17.700000       3794.900000    41.200000

# %% [markdown]
# # Visualizando e Analisando
